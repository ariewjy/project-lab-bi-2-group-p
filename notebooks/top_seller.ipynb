# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b910083-b763-405c-8da4-74f935ef4d85" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b910083-b763-405c-8da4-74f935ef4d85">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
order_items_data = pd.read_csv('olist_order_items_dataset.csv')
order_items_data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
persentase_null_values = order_items_data.isnull().sum()/len(order_items_data)*100
persentase_null_values
# Out:
# order_id               0.0
# order_item_id          0.0
# product_id             0.0
# seller_id              0.0
# shipping_limit_date    0.0
# price                  0.0
# freight_value          0.0
# dtype: float64

# %%
order_items_data.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
count_order_items_data = order_items_data['product_id'].value_counts()
count_order_items_data
# Out:
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# dbc42f8ad8afd0147a5a46be630781f8      1
# 5d86ed92606c80a89e547cdba3946812      1
# 0b8750fa58fefe42cf03a9e2e4b8fce6      1
# a4758e74e2cdb74d0c4db83594ca14a3      1
# 350688d9dc1e75ff97be326363655e01      1
# Name: product_id, Length: 32951, dtype: int64

# %%
count_order_items_data = order_items_data['seller_id'].value_counts()
count_order_items_data
# Out:
# 6560211a19b47992c3666cc44a7e94c0    2033
# 4a3ca9315b744ce9f8e9374361493884    1987
# 1f50f920176fa81dab994f9023523100    1931
# cc419e0650a3c5ba77189a1882b7556a    1775
# da8622b14eb17ae2831f4ac5b9dab84a    1551
#                                     ...
# 400f221ab83037c0ea78f1267da9624d       1
# 1746c1ae87ac63d530c7c943d0ac42e2       1
# 16bdc8cefd0e32a6f0824d296c5ad14a       1
# ace601496e211a664100321f038f50af       1
# 13d95f0f6f73943d4ceffad0fc2cd32c       1
# Name: seller_id, Length: 3095, dtype: int64

# %%
count_order_items_data = order_items_data['order_id'].value_counts()
count_order_items_data
# Out:
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 5a0911d70c1f85d3bed0df1bf693a6dd     1
# 5a082b558a3798d3e36d93bfa8ca1eae     1
# 5a07264682e0b8fbb3f166edbbffc6e8     1
# 5a071192a28951b76774e5a760c8c9b7     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: order_id, Length: 98666, dtype: int64

# %%
order_items_data['revenue'] = order_items_data['price'] * order_items_data['order_item_id']
order_items_data['revenue']
# Out:
# 0          58.90
# 1         239.90
# 2         199.00
# 3          12.99
# 4         199.90
#            ...
# 112645    299.99
# 112646    350.00
# 112647     99.90
# 112648     55.99
# 112649     43.00
# Name: revenue, Length: 112650, dtype: float64

# %%
count_top_seller = order_items_data.groupby([('revenue'), ('product_id')])['seller_id'].agg(np.sum).to_frame()
count_top_seller
# Out:
#                                                                                    seller_id
# revenue  product_id
# 0.85     8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e96804ea39d96eb...
# 1.20     270516a3f41dc035aa87d220228f844c                   2709af9587499e95e803a6498a5a56e9
# 1.70     8a3254bee785a526d548a81a9bc3c9be                   96804ea39d96eb908e7c3afdb671bb9e
# 2.20     46fce52cef5caa7cc225a5531c946c8b                   2d2322d842118867781fc737e96d59a1
# 2.29     310dc32058903b6416c71faff132df9e                   0e44d110fa6a54e121cb2c095a77762f
# ...                                                                                      ...
# 7160.00  19936fa4f614ee0590d3b77ac83fd648                   b37c4c02bda3161a7546a4e6d222d5b2
# 8400.00  5769ef0a239114ac3a854af00df129e4                   b37c4c02bda3161a7546a4e6d222d5b2
# 10080.00 5769ef0a239114ac3a854af00df129e4                   b37c4c02bda3161a7546a4e6d222d5b2
# ...

# %%
count_top_seller .value_counts().to_frame()
# Out:
#                                                       0
# seller_id
# 7c67e1448b00f6e969d365cea6b010ab                    439
# 4a3ca9315b744ce9f8e9374361493884                    346
# cca3071e3e9bb7d12640c9fbe2301306                    331
# da8622b14eb17ae2831f4ac5b9dab84a                    285
# 7142540dd4c91e2237acb7e911c4eba2                    278
# ...                                                 ...
# a61cc04793308395a840807104365121                      1
# 2e90cb1677d35cfe24eef47d441b7c872e90cb1677d35cf...    1
# a63bfbaa882c8f4542891b4e2246cc7fa63bfbaa882c8f4...    1
# a64e44665225d19dfc0277eeeaaccc57                      1
# 0015a82c2db000af6aaaf3ae2ecb05320015a82c2db000a...    1
#
# [8866 rows x 1 columns]

# %%
order_items_data = order_items_data.drop('shipping_limit_date', axis=1)
order_items_data = order_items_data.drop('freight_value', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-9294fd79cf02> in <module>
# ----> 1 order_items_data = order_items_data.drop('shipping_limit_date', axis=1)
#       2 order_items_data = order_items_data.drop('freight_value', axis=1)
#       3 order_items_data.head(5)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
order_items_data.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    revenue
# 0    58.90
# 1   239.90
# 2   199.00
# 3    12.99
# 4   199.90

# %%
order_items_data.to_csv(r'top seller.csv')
